# %%
#Scenario: You are developing a banking application that categorizes transactions based on the amount entered.
 #Write logic to determine whether the amount is positive, negative, or zero.

Entamt=int(input("Enter your amount:"))
if Entamt<0:
    print("Your amount is negative")
elif Entamt>0:
    print("Your amount is positive")
else:
    print("Your amount is zero")
# Out:
# Enter your amount: 0
# Your amount is zero

# %%
#2.	Scenario: A digital locker requires users to enter a numerical passcode. As part of a security feature, the system checks the sum of the digits of the passcode.
# Write logic to compute the sum of the digits of a given number.

num=input("Enter your passcode:")
total_sum=0
for each in num:
    total_sum = total_sum+int(each)
print(total_sum)
# Out:
# Enter your passcode: 9567
# 27

# %%
#3.	Scenario: A mobile payment app uses a simple checksum validation where reversing a transaction ID helps detect fraud.
 #Write logic to take a number and return its reverse.

chknum=input("Enter your passcode:")
right_code= 1234

if not chknum.isdigit():
    print("Enter passcode only in numbers")
elif right_code==int(chknum):
    print("Login successful")
elif right_code==int(chknum[::-1]):
    print("Fraud entry detected")
else:
    print("Wrong password..please try again.")
# Out:
# Enter your passcode: 4321
# Fraud entry detected

# %%
#4.	Scenario: In a secure login system, certain features are enabled only for users with prime-numbered user IDs.
# Write logic to check if a given number is prime.

prnum=int(input("Enter your number here:"))
if prnum<=1:
    print ("Enter a number greater than 1")
else:
    for i in range(2,prnum):
        if prnum%i==0:
            print("Entered number is not a prime number ")
            break
        else:
            print("Enter number is prime - User ID is successful")
            break
# Out:
# Enter your number here: 13
# Enter number is prime - User ID is successful

# %%
#5.	Scenario: A scientist is working on permutations and needs to calculate the factorial of numbers frequently.
# Write logic to find the factorial of a given number using recursion.

fact=int(input("Enter your number:"))
num=1
for x in range(1,fact+1):
    num=num*x
print(num)
# Out:
# Enter your number: 5
# 120

# %%
#6.	Scenario: A unique lottery system assigns ticket numbers where only Armstrong numbers win the jackpot.
 #Write logic to check whether a given number is an Armstrong number.

usernum=input("Enter your number here:")
root_value=len(usernum)
arm_num=0

for x in (usernum):
    arm_num += int(x)**root_value
if int(usernum)==arm_num:
    print("Entered numbers is Armstrong numbers")
else:
    print("Entered numbers is not a Armstrong numbers")
# Out:
# Enter your number here: 9474
# Entered numbers is Armstrong numbers

# %%
#7.	Scenario: A password manager needs to strengthen weak passwords by swapping the first and last characters of user-generated passwords.
# Write logic to perform this operation on a given string.

user_passwd=input("Enter your password")

if len(user_passwd) <=2:
    print(f"user password is :{user_passwd}")
else:
    strength_passwd=user_passwd[-1]+user_passwd[1:-1]+user_passwd[0]
    print(f"Strenght Password is:{strength_passwd}")
# Out:
# Enter your password HOPE AI
# Strenght Password is:IOPE AH

# %%
#8.	Scenario: A low-level networking application requires decimal numbers to be converted into binary format before transmission.
 #Write logic to convert a given decimal number into its binary equivalent.

#       16 8 4 2 1
# 25  -- 1 1 0 0 1  -- binary number

bin_num = int(input("Enter the number: "))
decimal_num=""

while bin_num >0:        #25 >0  --> True
    rem_value=bin_num%2  ##25%2  -- > reminder 1
    decimal_num=str(rem_value)+decimal_num    # 1+""  = 1 1 0 0 1
    bin_num=bin_num//2
print(decimal_num)
# Out:
# Enter the number:  25
# 11001

# %%
#9. Scenario: A text-processing tool helps summarize articles by identifying the most significant words.
 #Write logic to find the longest word in a sentence.

long_input=input("Enter your text here:")      ## Welcome to hope ai
split_word=long_input.split()                  ## ['Welcome', 'to', 'hope', 'ai']
long_word=""                                   ## empty string

for text in split_word:                        ##it sent string from the list because inside list all the value is in string format
    if len(text)>len(long_word):               ## first Welcome will come this len is 7 . so 7>None
        long_word=text                         ## now long_word=7    ---- > next loop will fail because  next word len is 2>7 fail and 4>7 fail and 2>7 fail
print(long_word)
# Out:
# Enter your text here: Welcome to hope ai
# ['Welcome', 'to', 'hope', 'ai']

# %%
#10.	Scenario: A plagiarism detection tool compares words from different documents and checks if they are anagrams (same characters but different order).
 #Write logic to check whether two given strings are anagrams.

anag_input1=input("Enter your text here:")
anag_input2=input("Enter your text here:")
anag_input1=anag_input1.lower().replace(" ","")
anag_input2=anag_input2.lower().replace(" ","")

sort1=sorted(anag_input1)
sort2=sorted(anag_input2)
if sort1==sort2:
    print("Entered text is anagrams")
else:
    print("Entered text is not anagrams")
# Out:
# Enter your text here: MALA ya LAM
# Enter your text here: M a L a Y a La m
# Entered text is anagrams
