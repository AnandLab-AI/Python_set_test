# %%
#1.What is wrong with the following function definition, and how do you fix it?

#Ans : Missed indentation ":" after the function and function call . executed the code and it completed .
def say_hello(name):
    print("Hello, " + name)
say_hello("hope ai")
# Out:
# Hello, hope ai

# %%
#2.What error will occur in the following code, and how do you fix it?

#Ans : 25 is integer , if we executed below code str cannot add with int  (Error : can only concatenate str (not "int") to str)

age = 25
print("I am " + str(age) + " years old")
# Out:
# I am 25 years old

# %%
#3.Question:
#What is the issue with the following code?
#Ans :code fixed -  Variable defined at inside function , removed variable from inside fun .

def greet(message):
    return message
message = "Hello"
print(message)
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?
##TypeError: add() missing 1 required positional argument: 'b'

def add(a, b):
    return a + b

print(add(5,10))   ## here we given only one argument , python will automatically assign the value 5 into a and then we will get error missing arugument like that
# Out:
# 15

# %%
#5.What is wrong with this code?
## We did not call func and passwd argument
def is_even(n):
    if n % 2 == 0:    ## if this code want to find even value true then we need to change here ==0 
        return True
    else:
        return False
is_even(5)
# Out:
# False

# %%
#6.What happens when you run this code?
##Valueerror python will allow only the int value since we used int() , if we remove int it will execute

#num = int("10a")
#print(num)


num1 = "10a"
print(num1)
# Out:
# 10a

# %%
#7.What will happen when you run the following code?
##Attributeerror
## it will reverse [4,3,2,1] since already list in the asc order
numbers = [1, 2, 3, 4]
numbers.sort() 
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers.append(4)  ##append will return None value also append will add the new value in the end of list
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?
#UnboundLocalError: cannot access local variable 'count' where it is not associated with a value

count = 10

def increment(count):
    count += 1
    print(count)

increment(count)
# Out:
# 11

# %%
#10.What error will occur in the following code?

    ### 012345  =index value 
text = "Python"
print(text[5])  ##Here you calling index 10 it will return the error "IndexError: string index out of range"
# Out:
# n
