# %%
#1.	Scenario: A user is required to enter a valid number in a form, but users sometimes input invalid data.
# Write logic to repeatedly prompt the user until they enter a valid integer.


1.Get the input from user
2.will use while loop for this scenario
3.until user enter right code it will ask again
4.i will use break it will prevent to ask again to enter the code to user if he entered right code

# %%
#2.	Scenario: A data analysis tool processes a list of numbers and needs to identify the most frequently occurring value.
# Write logic to find the most frequently occurring number in a given list.

1.Get the list with repeated value
2.use for loop and remove the duplicate value using set
3.count the value ( inside the loop create one new variable and count the value using exisiting list and the value come from for loop )
4.if count value is > 1 it will count

#L1=[1,2,2,3,4,4,4,5,1,1]
#for val in set(L1):  ## Here i am removing all the duplicate value
#    C1=L1.count(val)
#    if C1 >1:
#        print(f"{val} and count is :{C1} times")
# Out:
# 1 and count is :3 times
# 2 and count is :2 times
# 4 and count is :3 times

# %%
#3.	Scenario: A text-processing application needs to compare words and check if they are anagrams (contain the same letters in a different order).
# Write logic to determine whether two given strings are anagrams.


1.get the input from user ( str ) format
2.use lower and replace function if the input contains upper and space
3.user sorted fncntion and it has return so assign the value in to new variable
4.use if class check intial variable and sorted variable in equal 
5. if it equal it anagram else not anagrams

# %%
#4.	Scenario: A speech analysis program needs to count the number of vowel sounds in a given input.
# Write logic to count the number of vowels in a given string.

1.get the user input  eg : user_input=""
2.create variables and assign vowels letter to that  eg : vow
3.use for loop eg : i in user_input:
4.use if condition eg : i.lower() in vow
5.count the value

# %%
#5.	Scenario: A text-editing software includes a feature to reverse the order of words in a sentence for stylistic effects.
# Write logic to reverse the order of words in a sentence while keeping the words themselves intact.

1. get the user input in string format eg : user_input="Enter you words here:"
2. use split function to split the word and return the output to new variable eg : sp_words=user_input.split()
3. use [::-1] slicing to reverse the words and assign it into new variable . eg : re_words=sp_words[::-1]
4. if we print the variable re_words it will diplay the output in revers but it display in tuple format
5. use empty white space "".join(re_words))

# %%
#6.	Scenario: A missing number is detected in a sequence of values stored in a database.
# Write logic to find the missing number in a list containing n-1 numbers from 1 to n.

1.get the number in list format eg :List1=[1,2,3,5,7]  ## here missing number is 4 and 6
2.here n value is 7 eg : n=7
3.use for to feed each value from list eg : for i in range (1,n+1)  ## here n is 7 
4.inside for use if condition eg : if i not in List1 :
5.if any value not there in existing list it will give that number mi_value=i
5 print that value

# %%
#7.	Scenario: An ATM machine processes withdrawal requests and needs to ensure that users cannot withdraw more than their account balance.
 #Write logic to allow a withdrawal only if the balance is sufficient.

1. your balance amount in account eg : - Balance=2500
2. enter your withdraw amount - withdraw=("Enter your withdraw amount")
3. use if class to check if Balance <= withdraw: print sufficient amount else insufficient amount

# %%
#8.	Scenario: A system needs to verify whether a given dataset contains duplicate entries.
# Write logic to check whether a given list contains duplicate values.

1.get the list  eg L1=[1,2,3,3,4,4,5]
2.use set data types L2=list(set(L1))
3.you list is equal to set - your list not contain any duplicate else it has duplicate value if len(L1)==len(L2)

# %%
#9.	Scenario: A digital calculator includes a feature to sum the digits of a number for verification purposes.
# Write logic to calculate the sum of all digits in a given integer.

1. get the user input eg: E1=("enter your number here:")
2. create one dummy variable assign value to 0 eg : C1=0
3.use for loop eg : for i in E1:
4 C1=int(i)+C1
5. you will get sum of number when you print C1

# %%
#10.	Scenario: A language-learning app wants to verify whether a given sentence is a pangram (contains every letter of the alphabet at least once).
# Write logic to check if a given sentence is a pangram.

1.create a variable and assign letter a- z 
2.get the sentence from user
3.if user letters is in variables without missing any words it is pangram else not pangram
