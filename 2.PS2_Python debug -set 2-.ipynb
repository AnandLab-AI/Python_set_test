# %%
#1.Find the error in the following Python code:
#Ans : print(math.sqrt(16))
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
##Ans : Argument not mentioned in the function :
def my_function(x):
    x += 5
    print(x)

x = 10
my_function(x)
# Out:
# 15

# %%
#And: Variable not declare and syntax error ( if x==10) so it will throw error

x = 5
if x == 10:
    print("x is 10")
else:
    print("x is :",x)
# Out:
# x is : 5

# %%
#4.Code fixed
numbers = [5, 3, 8, 2]
print(sorted(numbers))
# Out:
# [2, 3, 5, 8]

# %%
#5. retrun missing , code fixed
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
#6. Tuple is immutable once list created it cant change , changed () to []
my_tuple = [1, 2, 3]
my_tuple[1] = 5
print(my_tuple)
# Out:
# [1, 5, 3]

# %%
#7. i have used f string
name = "Alice"
age = 25
print(f"My name is {name} and I am {age} years old" )
# Out:
# My name is Alice and I am 25 years old

# %%
#8. instead is changed to ==
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.Seems it is reverse range 
for i in range(5, 1,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10. here key value is str so we have to give ""
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
