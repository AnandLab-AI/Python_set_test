# %%
#1.Find the error in the following Python code:
##code corrected
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?
#Ans : Error
#Code corrected
a = 10
b = 5
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 a = 10
#       4 b = "5"
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#3.What is the issue in this Python snippet?
##Corrected : missing in the function 
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:
# Indentation error in numbers and List index will start from 0 , here 0,1,2,3 and there is no 4 it out of range will not return any value
numbers = [1, 2, 3, 4]
print(numbers[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 #4.Identify the bug in the following Python code:
#       2 # Indentation error in numbers and List index will start from 0 , here 0,1,2,3 and there is no 4 it out of range will not return any value
#       3 numbers = [1, 2, 3, 4]
# ----> 4 print(numbers[4])
#
# IndexError: list index out of range

# %%
#5.Find the error in the following Python code:
## Python print function syntax is print() here there is no () so it will thorw error , code corrected .
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
## Ans is Error division error
x = 5 / 0

# %%
#7.Find the error in the following Python code:name = "Alice"
## Error name is not defined and TypeError: can only concatenate str (not "int") to str
name="Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
## Jump value will work from higher to lower not lower to higher 
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
#Error : SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

x = 10
if x == 5:
    print("x is 5")
else:
    print("x is not 5")
# Out:
# x is not 5

# %%
#10. Identify the error in the following function definition:
##Argument not passed and indentation error

def greet(name):
    print("Hello, " + name)
greet("Anand")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       4 def greet(name):
#       5     print("Hello, " + name)
# ----> 6 greet(Anand)
#
# NameError: name 'Anand' is not defined
